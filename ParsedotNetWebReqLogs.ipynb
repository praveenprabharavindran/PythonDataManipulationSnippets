# %% [markdown]
# <a href="https://colab.research.google.com/github/praveenprabharavindran/PythonDataManipulationSnippets/blob/main/ParsedotNetWebReqLogs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
from google.colab import files

uploaded = files.upload()
file_name = list(uploaded.keys())[0]

multiline_string = uploaded[file_name].decode('utf-8')
# Out:
#      <input type="file" id="files-0405f71c-2f82-4080-93d0-e770efbc64e7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0405f71c-2f82-4080-93d0-e770efbc64e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(multiline_string)
# Out:
# 08/06/23 13:13:06:941 trce: Grpc.AspNetCore.Server.Model.Internal.ServiceRouteBuilder[2] Discovering gRPC methods for Dell.Buyer.ShcPo.Grpc.Services.ShcPoService.
# 08/06/23 13:13:07:034 trce: Grpc.AspNetCore.Server.Model.Internal.ServiceRouteBuilder[1] Added gRPC method 'CreateShcQuote' to service 'shcpoapi.Shc'. Method type: Unary, HTTP method: POST, route pattern: '/shcpoapi.Shc/CreateShcQuote'.
# 08/06/23 13:13:07:057 trce: Grpc.AspNetCore.Server.Model.Internal.ServiceRouteBuilder[2] Discovering gRPC methods for Grpc.Reflection.ReflectionServiceImpl.
# 08/06/23 13:13:07:069 trce: Grpc.AspNetCore.Server.Model.Internal.ServiceRouteBuilder[1] Added gRPC method 'ServerReflectionInfo' to service 'grpc.reflection.v1alpha.ServerReflection'. Method type: DuplexStreaming, HTTP method: POST, route pattern: '/grpc.reflection.v1alpha.ServerReflection/ServerReflectionInfo'.
# 08/06/23 13:13:08:172 info: Microsoft.Hosting.Lifetime[14] Now listening on: https://localhost:5198
# ...

# %%
pattern = r"(?P<method>GET|POST|DELETE|PUT)\s+(?P<url>https?:\S+)\s+.*?after\s+(?P<receiveTime>\d+\.\d+)ms.*\s+.*after\s+(?P<endTime>\d+\.\d+)ms\s-\s(?P<status>\d+)"

matches = re.finditer(pattern, multiline_string, re.MULTILINE)

# %%
table_header = "|".join(["Url", "Method", "ReceiveTime", "EndTime", "Status"])
print(table_header)
print("-" * len(table_header))

for match in matches:
    url = match.group("url")
    method = match.group("method")
    receive_time = match.group("receiveTime")
    end_time = match.group("endTime")
    status = match.group("status")

    table_row = "|".join([url, method, receive_time, end_time, status])
    print(table_row)
# Out:
# Url|Method|ReceiveTime|EndTime|Status
# -------------------------------------
# https://buyer-logger-perf-1.pnp1.pcf.dell.com/log|POST|452.4846|543.0648|202
# https://buyer-logger-perf-1.pnp1.pcf.dell.com/log|POST|71.2699|80.8859|202
# https://b2bdatasvcapi-perf.r2.pcf.dell.com/api/SellerHosted/CatalogDetailsWithQuoteId/3000000100981?isPreview=false|GET|1390.6304|1435.7602|200
# https://quote-svc.perf1.dell.com/v3/quotes/q3A29nWieUKDSCuQ7huEBw|GET|750.9113|759.3816|200
# https://buyer-logger-perf-1.pnp1.pcf.dell.com/log|POST|819.7855|828.5901|202
# https://item-snapshot-svc.perf1.dell.com/v1/items/7JOSbPNFq0ucIc081OEWew~001/openBasketLite|GET|648.5555|665.5126|200
# https://item-snapshot-svc.perf1.dell.com/v1/items/vTRCJ01oOkiGRgnB17o6gw~001/openBasketLite|GET|114.9976|141.4345|200
# https://item-snapshot-svc.perf1.dell.com/v1/items/we_dlXCl90icYjxJx3fe2g~001/openBasketLite|GET|127.5626|137.0299|200
# ...
